# %%
import pystan
import arviz

# %% [markdown]
# # this code is for bernoully experiencing

# %%
sm = pystan.StanModel(model_code=schools_code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_19a09b474d1901f191444eaf8a6b8ce2 NOW.

# %%
fit = sm.sampling(data=schools_dat, iter=1000, chains=4, control = {"adapt_delta" : 0.9})

# %%
plt = fit.plot()
# Out:
# WARNING:pystan:Deprecation warning. PyStan plotting deprecated, use ArviZ library (Python 3.5+). `pip install arviz`; `arviz.plot_trace(fit)`)

# %%
plt.show()
# Out:
# C:\Users\Tomer\Anaconda3\envs\stan_env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.
